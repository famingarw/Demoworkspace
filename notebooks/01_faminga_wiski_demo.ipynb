# %% [markdown]
# # Faminga WiSK Demo Notebook
#
# Use this notebook to practice VS Code Jupyter workflows from the VS Code guide: select the project virtual environment as the kernel, run cells, inspect variables, and connect notebook work back to reusable Python scripts.

# %% [markdown]
# ## 1. Load the Synthetic Field Dataset
#
# The dataset is safe for training and does not include live farmer records.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

src_path = PROJECT_ROOT / "src"
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

from faminga_wiski_demo.soil_rules import load_field_rows, recommendation_for_field, summarize_fields

data_path = PROJECT_ROOT / "data" / "synthetic_faminga_fields.csv"
rows = load_field_rows(data_path)
rows[:2]

# %% [markdown]
# ## 2. Build Baseline Recommendations
#
# The recommendation logic is deliberately simple. The objective is to make the workflow explainable before mentees extend it.

# %%
summary = summarize_fields(rows)
summary

# %%
recommendations = [recommendation_for_field(row) for row in rows]
sorted(recommendations, key=lambda item: item.risk_score, reverse=True)[:5]

# %% [markdown]
# ## 3. Mentee Reflection
#
# - Which variable seems most important for field intervention priority?
# - Which output can be translated into a low-literacy farmer message?
# - What data would Faminga need before using this workflow for live Phase II scaling?
